# %%
#arithemetic opertors exmpals
a=10
b=20
add=a+b
sub=a-b
multi=a*b
div=a/b
floor_div=a//b
modules=a%b

exponet=a**b

print(add)
print(sub)
print(multi)
print(div)
print(floor_div)
print(modules)
print(exponet)
# Out:
# 30
# -10
# 200
# 0.5
# 0
# 10
# 100000000000000000000

# %%
#comparion operators
# == equle to
a=10
b=20

a==b
# Out:
# False

# %%
str1="arun"
str2="arun"

str1==str2
# Out:
# True

# %%
#Not equal to
str1!=str2
# Out:
# False

# %%
str3="arun"
str4="Arun"

str3!=str4
# Out:
# True

# %%
#greater than or less than
num1=50
num2=45

num1>num2
# Out:
# True

# %%
print(num1<num2)
# Out:
# False

# %%
#greater than or less than or equal to
num3=45
num4=45

print(num3>=num4)
# Out:
# True

# %%
#greater than or less than or equal to
print(num3<=num4)
# Out:
# True

# %%
## And ,Not,OR
x=True
y=True

z= y and x
print(y)
# Out:
# True

# %%
x=False
y=True

z=x and y
print(z)
# Out:
# False

# %%
## OR
x=False
y=False
z=x or y
print(z)
# Out:
# False

# %%
#NOT Operators
x=False
not x
# Out:
# True

# %%
#simpale calculator
num1=float(input("Enter Frist Number")) ##10
num2=float(input("Enter Second Number ")) ##20

addition=num1+num2
substraction=num1-num2
multiplication=num1*num2
divion=num1/num2
floor_div=num1//num2
modules=num1%num2
exponet=num1**num2

print("addition:",addition)
print("substraction:",substraction)
print("multiplication:",multiplication)
print("divion:",divion)
print("floor_div:",floor_div)
print("modules:",modules)
print("exponet:",exponet)
# Out:
# addition: 30.0
# substraction: -10.0
# multiplication: 200.0
# divion: 0.5
# floor_div: 0.0
# modules: 10.0
# exponet: 1e+20
