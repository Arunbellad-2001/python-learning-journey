# %%
#if condition 
age=18
if age>=18:
    print("you are elgible for vote")
# Out:
# you are elgible for vote

# %%
#else condition 
age=17
if age<=20:
    print("you are teen ager")
else:
    print("your are adult")
# Out:
# you are teen ager

# %%
#elif condtion
age=int(input("enter your age")) #20
if age<=13:
    print("you are a child")
elif age<=20:
    print("you are a teenager")
else:
    print("you are adult")
# Out:
# you are a teenager

# %%
#neasted condtions
# You can place one or more if, elif, or else statements inside another if, elif, or else statement to create nested conditional statements.

## number even ,odd,negative

num=int(input("enter a number"))
if num>0:
    print("number is positive")
    if num%2==0:
        print("the number is even")
    else:
        print("number is add number")
else:
    print("number is negative or zero")
# Out:
# number is negative or zero

# %%
## Practical Examples

## Determine if a year is a leap year using nested condition statement

num=int(input("entr a year"))
if num%4==0:
    if num%100==0:
        if num%4==0:
            print(num,"is a leaf year")
        else:
            print(num,"is not leaf year")
    else:
        print(num,"is a leaf year")
else:
    print(num,"is not leaf year")
# Out:
# 2564 is a leaf year

# %%
#simpale calculater using nesated statement
# Take user input

num1=int(input("enter frist number")) #3
num2=int(input("enter second number")) #2
operation=input("+,-,*,/") #/

if operation== '+' :
    result=num1+num2
elif operation=='-':
    result=num1-num2
elif operation== '*':
    result=num1*num2
elif operation=='/':
    if num2!=0:
        result=num1/num2
    else:
        result= "error ! not divion by zero"
else:
    result="invalid opertion"
    
print("result:",result)
# Out:
# result: 0.6666666666666666

# %%
### Determine the ticket price based on age and whether the person is a student.
# Ticket pricing based on age and student status

age=int(input("enter your age"))

if age<=7:
    price="free"
elif age<=12:
    price="$10"
elif age<=10:
    is_student=input("are you a student? (yes/no)").lower()
    if is_student =='yes':
        price="$20"
    else:
        price="$40"
elif age<=64:
    is_student=input("are you a student? (yes/no)").lower()
    if is_student=='yes':
        price="$20"
    else:
        price="$50"
else:
    price="$100"
print("ticket price:",price)
# Out:
# ticket price: $20

# %%
# Employee bonus calculation

year_of_service=int(input("enter your service:"))
performance_rating=float(input("enter your rating point(1.0 to 2.5):"))


if year_of_service>10:
    if performance_rating>=4.5:
        bounus_percentage=20
    elif performance_rating>3.5:
        bounus_percentage=15
    else:
        bounus_percentage=10
elif year_of_service>5:
    if performance_rating>=4.5:
        bounus_percentage=15
    elif performance_rating>3.5:
        bounus_percentage=10
    else:
        bounus_percentage=5
else:
    bounus_percentage=0

salary=float(input("enter your salary amount:"))
bounus_amount=salary*bounus_percentage/100
print("bounus amount :${:.2f}".format(bounus_amount))
# Out:
# bounus amount :$3000.00

# %%
# User login system

# Predefined username and password

stored_uesername="Arun"
stored_password="Arun@2001"

username=input("enter username")
password=input("enter password:")

if username==stored_uesername:
    if password==stored_password
        print("login seccfully")
    else:
        print("incorret password")
else:
    print("user not pound")
# Out:
# login seccfully
