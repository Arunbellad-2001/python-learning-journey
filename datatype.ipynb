# %%
#basic datatypes
var_int=25
var_name="arun"
var_float=5.66
var_boolean=True

print(var_int,type(var_int))
print(var_name)
print(var_float)
print(var_boolean)
# Out:
# 25 <class 'int'>
# arun
# 5.66
# True

# %%
#intgers
age=35
print(age)
# Out:
# 35

# %%
#floating pointss datatypes
height=1.636
print(height)
print(type(height))
# Out:
# 1.636
# <class 'float'>

# %%
num=2500.66
print(f"mobile series number :{num},type{type(num)}")
# Out:
# mobile series number :2500.66,type<class 'float'>

# %%
#string data types
name="Arun"
print(name)
print(type(name))
# Out:
# Arun
# <class 'str'>

# %%
## boolean datatype
is_true=True
type(is_true)
# Out:
# bool

# %%
a=20
b=20

print(a==b)
type(a==b)
# Out:
# True
# bool

# %%
result="hello"+ str(5)
print(result)
# Out:
# hello5

# %%
name="arun"+"bellad"+"age"+str(25)
age=25+56
print(name)
print(age)
# Out:
# arunbelladage25
# 81
